# %% [markdown]
# # Simulations numériques du rapport du COR de Juin 2019

# %%
from SimulateurRetraites import SimulateurRetraites
from SimulateurAnalyse import SimulateurAnalyse
import pylab as pl

# %% [markdown]
# ## Hypothèses : conjoncture

# %%
simulateur = SimulateurRetraites('../retraites/fileProjection.json')

analyse = simulateur.pilotageCOR()

pl.figure(figsize=(10,8))
pl.suptitle(u"Projections du COR (hypothèses)",fontsize=16)
for c in range(9):
    pl.subplot(3,3,c+1)
    v,V = [ (simulateur.B,'B'), (simulateur.NR,'NR'), (simulateur.NC,'NC'), \
            (simulateur.G,'G'), (simulateur.dP,'dP'), (simulateur.TCR,'TPR'), 
            (simulateur.TCS,'TPS'), (simulateur.CNV,'CNV'), (simulateur.EV,'EV') ][c]
    analyse.graphique(v,V)
pl.tight_layout(rect=[0, 0.03, 1, 0.95])

# %% [markdown]
# ## Statu quo (COR)
#
# Cette stratégie de pilotage est celle du COR en 2019.

# %%
simulateur = SimulateurRetraites('../retraites/fileProjection.json')

analyse = simulateur.pilotageCOR()

titre = 'Projections du COR (Juin 2019)'
pl.figure(figsize=(6,8))
pl.suptitle(titre,fontsize=16)
analyse.graphiques()

# %%
analyse.graphique(analyse.RNV,"RNV",draw_legend=True, scenarios_indices=range(1,5))
pl.suptitle(titre);

# %%
analyse.graphique(analyse.Depenses,"Depenses")
analyse.plot_legend()

# %%
analyse.graphique(analyse.Depenses,"Depenses",draw_legend=True,scenarios_indices=range(1,5))
pl.plot([2000,2070],[0.14]*2, linewidth=4.0);
pl.legend(["+1,8%", "+1,5%", "+1,3%", "+1%","Règle d'or imaginée"]);

# %%
analyse.graphique(analyse.Depenses,"Depenses",draw_legend=True,scenarios_indices=range(1,5))
s = 3
regleor_reelle = [ analyse.Depenses[s][a] for a in analyse.annees ]
pl.plot(analyse.annees,regleor_reelle, linewidth=4.0);
pl.legend(["+1,8%", "+1,5%", "+1,3%", "+1%","Règle d'or étude impact"]);

# %%
analyse.affiche_variable(analyse.Depenses)
# Out:
# Scenario 1 :  Hausse des salaires: +1,8%/an, Taux de chômage: 7%
# 2020 : 0.136
# 2025 : 0.137
# 2030 : 0.136
# 2040 : 0.128
# 2050 : 0.121
# 2060 : 0.116
# 2070 : 0.116
#
#
# Scenario 2 :  Hausse des salaires: +1,5%/an, Taux de chômage: 7%
# 2020 : 0.136
# 2025 : 0.137
# 2030 : 0.137
# 2040 : 0.132
# 2050 : 0.128
# 2060 : 0.125
# 2070 : 0.126
#
#
# Scenario 3 :  Hausse des salaires: +1,3%/an, Taux de chômage: 7%
# 2020 : 0.136
# 2025 : 0.137
# 2030 : 0.138
# 2040 : 0.136
# 2050 : 0.133
# 2060 : 0.131
# 2070 : 0.133
#
#
# Scenario 4 :  Hausse des salaires: +1%/an, Taux de chômage: 7%
# 2020 : 0.136
# 2025 : 0.137
# 2030 : 0.139
# 2040 : 0.141
# 2050 : 0.141
# 2060 : 0.141
# 2070 : 0.144
#
#
# Scenario 5 :  Hausse des salaires: +1,8%/an, Taux de chômage: 4.5%
# 2020 : 0.136
# 2025 : 0.135
# 2030 : 0.133
# 2040 : 0.124
# 2050 : 0.118
# 2060 : 0.114
# 2070 : 0.114
#
#
# Scenario 6 :  Hausse des salaires: +1%/an, Taux de chômage: 10%
# 2020 : 0.136
# 2025 : 0.139
# 2030 : 0.143
# ...
